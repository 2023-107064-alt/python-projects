# %% [markdown]
# <a href="https://colab.research.google.com/github/2023-107064-alt/python-projects/blob/main/Bayesian_Parts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.stats as sts
import numpy as np
import matplotlib.pyplot as plt

mu = np.linspace(1.65, 1.8, num = 50)
test = np.linspace(0, 2)
uniform_dist = sts.uniform.pdf(mu) + 1

uniform_dist = uniform_dist/uniform_dist.sum()
beta_dist = sts.beta.pdf(mu, 2, 5, loc = 1.65, scale = 0.2)
beta_dist = beta_dist/beta_dist.sum()
plt.plot(mu, beta_dist, label = 'Beta Dist')
plt.plot(mu, uniform_dist, label = 'Uniform Dist')
plt.xlabel("Value of $\mu$ in meters")
plt.ylabel("Probability density")
plt.legend()
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-447/4285847488.py:14: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Value of $\mu$ in meters")

# %%
def likelihood_func(datum, mu):
  likelihood_out = sts.norm.pdf(datum, mu, scale = 0.1)
  return likelihood_out/likelihood_out.sum()

likelihood_out = likelihood_func(1.7, mu)

plt.plot(mu, likelihood_out)
plt.title("Likelihood of $\mu$ given observation 1.7cm")
plt.ylabel("Probability Density/Likelihood")
plt.xlabel("Value of $/mu$")
plt.chow()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-447/1231250082.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.title("Likelihood of $\mu$ given observation 1.7cm")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-447/1231250082.py in <cell line: 0>()
#       9 plt.ylabel("Probability Density/Likelihood")
#      10 plt.xlabel("Value of $/mu$")
# ---> 11 plt.chow()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'chow'

# %%
import scipy as sp

unnormalized_posterior = likelihood_out * uniform_dist
plt.plot(mu, unnormalized_posterior)
plt.xlabel("$\mu$ in meters")
plt.ylabel("Unnormalized Posterior")
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-447/3529792179.py:5: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("$\mu$ in meters")

# %%
unnormalized_posterior.sum()
# Out:
# np.float64(0.019999999999999997)
